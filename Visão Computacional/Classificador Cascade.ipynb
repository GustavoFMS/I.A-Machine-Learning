# %% [markdown]
# # Classificador Cascade

# %% [markdown]
# ##### Técnica usada para detecção de faces e objetos

# %% [markdown]
# • O treinamento da I.A é baseado em 2 conjuntos de imagem:
# <br /> 1. Imagens das faces
# <br /> 2. Imagens de qualquer outra coisa menos fácies. <br />
#
# • Exemplo: se sua função é detectar carros, suas **imagens positivas** serão os carros e as **imagens negativas** outras imagens que não são carros, para o algoritmo treinar sua detecção <br />

# %% [markdown]
# ##### Treinamento Adaboost

# %% [markdown]
# • Basicamente aplica-se o algoritmo **Adaboost** tanto sobre as imagens positivas, quanto as imagens negativas. <br/>
# • Objetivo: é a fazer a seleção das caracteristicas.

# %% [markdown]
# ##### Seleção das caracteristicas

# %% [markdown]
# • Para realizar, basta aplicar esses **quadradinhos** para cada **sub janela** de uma imagem.<br/>
# ![image.png](attachment:image.png)
#
# • O conceito de **janela** indica que ele vai andando da esquerda para a direita e de cima para baixo andando <br/>
# > Formula: Soma pixels brancos - soma de pixels pretos<br/><br/>
# *OBS: O resultado final é uma matriz com valores inteiros*<br/>
# Exemplo do treinamento:<br/>
# ![image.png](attachment:image-2.png)

# %% [markdown]
# Depois que o algorítimo é treinado com as imagens, caso você use o open CV, é gerado um arquivo com a extensão xml que vai ter todas essas características e quando você quiser fazer uma nova classificação você simplesmente carregue o arquivo XML e ele vai identificar os pontos onde estão as imagens.
